# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
import os
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from PIL import Image

# %%
file_path = "C:/Users/jiash/OneDrive/Desktop/deep_learning/base_data/training/bows/Screenshot 2024-07-09 215332.png"
img = image.load_img(file_path)
plt.imshow(img)

# %%
cv2.imread(file_path)
# Out:
# array([[[234, 232, 230],
#         [234, 232, 230],
#         [235, 233, 231],
#         ...,
#         [228, 226, 226],
#         [229, 227, 227],
#         [229, 227, 227]],
#
#        [[234, 232, 230],
#         [234, 232, 230],
#         [235, 233, 231],
#         ...,
#         [228, 226, 226],
#         [229, 227, 227],
#         [229, 227, 227]],
#
#        [[234, 232, 230],
#         [234, 232, 230],
#         [235, 233, 231],
#         ...,
#         [228, 226, 226],
#         [229, 227, 227],
#         [229, 227, 227]],
#
#        ...,
#
#        [[221, 219, 219],
#         [221, 219, 219],
#         [221, 219, 219],
#         ...,
#         [218, 217, 219],
#         [218, 217, 219],
#         [218, 217, 219]],
#
#        [[221, 219, 219],
#         [221, 219, 219],
#         [221, 219, 219],
#         ...,
#         [218, 217, 219],
#         [218, 217, 219],
#         [218, 217, 219]],
#
#        [[221, 219, 219],
#         [221, 219, 219],
#         [221, 219, 219],
#         ...,
#         [218, 217, 219],
#         [218, 217, 219],
#         [218, 217, 219]]], dtype=uint8)

# %%
train = ImageDataGenerator(rescale = 1/255)
validation = ImageDataGenerator(rescale = 1/255)

# %%
train_file_path = "C:/Users/jiash/OneDrive/Desktop/deep_learning/base_data/training/"
validation_file_path = "C:/Users/jiash/OneDrive/Desktop/deep_learning/base_data/validation"
train_dataset = train.flow_from_directory(train_file_path,
                                          target_size = (200,200),
                                          batch_size = 3,
                                          class_mode = 'binary')
validation_dataset = train.flow_from_directory(validation_file_path,
                                          target_size = (200,200),
                                          batch_size = 3,
                                          class_mode = 'binary')
# Out:
# Found 72 images belonging to 2 classes.
# Found 17 images belonging to 2 classes.

# %%
train_dataset.class_indices
# Out:
# {'bows': 0, 'no_bows': 1}

# %%
model = tf.keras.models.Sequential([ tf.keras.layers.Conv2D(16,(3,3),activation = 'relu',input_shape = (200,200,3)),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    #
                                    tf.keras.layers.Conv2D(32,(3,3),activation = 'relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    #
                                    tf.keras.layers.Conv2D(64,(3,3),activation = 'relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    ##
                                    tf.keras.layers.Flatten(),
                                    ##
                                    tf.keras.layers.Dense(512, activation = 'relu'),
                                    ##
                                    tf.keras.layers.Dense(1, activation = 'sigmoid') 
                                    # multiclass ke liye softmax aur binary ke liye sigmoid
                                        
                                                            ])
# Out:
# C:\Users\jiash\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss = 'binary_crossentropy',
              optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.001),
            metrics = ['accuracy']
                       )

# %%
model_fit = model.fit(train_dataset, steps_per_epoch=5, epochs=30, validation_data=validation_dataset)
# Out:
# Epoch 1/30
# C:\Users\jiash\AppData\Roaming\Python\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 182ms/step - accuracy: 0.2907 - loss: 6.8477 - val_accuracy: 0.5294 - val_loss: 0.7942
# Epoch 2/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 185ms/step - accuracy: 0.5500 - loss: 0.8997 - val_accuracy: 0.5294 - val_loss: 0.9432
# Epoch 3/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - accuracy: 0.3463 - loss: 1.1512 - val_accuracy: 0.5294 - val_loss: 0.6810
# Epoch 4/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.4324 - loss: 0.7070 - val_accuracy: 0.7647 - val_loss: 0.6689
# Epoch 5/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step - accuracy: 0.7333 - loss: 0.6125 - val_accuracy: 0.5882 - val_loss: 0.6702
# Epoch 6/30
# C:\Program Files\Python311\Lib\contextlib.py:155: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - accuracy: 0.7491 - loss: 0.6130 - val_accuracy: 0.6471 - val_loss: 0.7057
# Epoch 7/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - accuracy: 0.6481 - loss: 0.6006 - val_accuracy: 0.5294 - val_loss: 0.6856
# Epoch 8/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.6889 - loss: 0.5732 - val_accuracy: 0.4706 - val_loss: 1.2332
# Epoch 9/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - accuracy: 0.5370 - loss: 1.0858 - val_accuracy: 0.9412 - val_loss: 0.5298
# Epoch 10/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step - accuracy: 0.6667 - loss: 0.4719 - val_accuracy: 0.8235 - val_loss: 0.4786
# Epoch 11/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 156ms/step - accuracy: 0.4324 - loss: 0.8757 - val_accuracy: 1.0000 - val_loss: 0.4494
# Epoch 12/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.8454 - loss: 0.4925 - val_accuracy: 0.7647 - val_loss: 0.4701
# Epoch 13/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - accuracy: 0.8259 - loss: 0.3712 - val_accuracy: 0.8824 - val_loss: 0.3532
# Epoch 14/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 195ms/step - accuracy: 0.9778 - loss: 0.2627 - val_accuracy: 0.4706 - val_loss: 1.7578
# Epoch 15/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - accuracy: 0.7222 - loss: 0.7964 - val_accuracy: 0.9412 - val_loss: 0.3239
# Epoch 16/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 184ms/step - accuracy: 0.9454 - loss: 0.2536 - val_accuracy: 0.9412 - val_loss: 0.2321
# Epoch 17/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 175ms/step - accuracy: 0.8630 - loss: 0.2756 - val_accuracy: 0.9412 - val_loss: 0.2038
# Epoch 18/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 1.0000 - loss: 0.1346 - val_accuracy: 0.9412 - val_loss: 0.2162
# Epoch 19/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 189ms/step - accuracy: 0.9417 - loss: 0.1481 - val_accuracy: 0.5882 - val_loss: 1.0897
# Epoch 20/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - accuracy: 0.7222 - loss: 0.3813 - val_accuracy: 1.0000 - val_loss: 0.2042
# Epoch 21/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - accuracy: 0.9778 - loss: 0.1471 - val_accuracy: 0.9412 - val_loss: 0.1742
# Epoch 22/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 187ms/step - accuracy: 0.9778 - loss: 0.0678 - val_accuracy: 0.9412 - val_loss: 0.1461
# Epoch 23/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 186ms/step - accuracy: 0.9639 - loss: 0.1357 - val_accuracy: 0.5882 - val_loss: 1.2265
# Epoch 24/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 182ms/step - accuracy: 0.7250 - loss: 0.9650 - val_accuracy: 1.0000 - val_loss: 0.1433
# Epoch 25/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - accuracy: 1.0000 - loss: 0.1866 - val_accuracy: 0.9412 - val_loss: 0.1834
# Epoch 26/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 192ms/step - accuracy: 1.0000 - loss: 0.0155 - val_accuracy: 0.9412 - val_loss: 0.1646
# Epoch 27/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 195ms/step - accuracy: 0.8620 - loss: 0.1845 - val_accuracy: 0.9412 - val_loss: 0.1989
# Epoch 28/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - accuracy: 0.9778 - loss: 0.1609 - val_accuracy: 1.0000 - val_loss: 0.1520
# Epoch 29/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - accuracy: 1.0000 - loss: 0.1464 - val_accuracy: 1.0000 - val_loss: 0.0599
# Epoch 30/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - accuracy: 1.0000 - loss: 0.0606 - val_accuracy: 0.9412 - val_loss: 0.1080

# %%
image_path = "C:/Users/jiash/OneDrive/Desktop/deep_learning/base_data/testing/"
for i in os.listdir(image_path):
    img=image.load_img(image_path+ str(i),target_size=(200,200))
    plt.imshow(img)
    plt.show()

    X=image.img_to_array(img)
    X=np.expand_dims(X,axis=0)
    images=np.vstack([X])
    val=model.predict(images)
    if val==0:
        print("it has bows")
    else:
        print("does not have bows")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# it has bows
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# it has bows
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# does not have bows
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# does not have bows
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# does not have bows
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# does not have bows
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# does not have bows
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# does not have bows
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# does not have bows
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# does not have bows
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# does not have bows
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# it has bows
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# it has bows
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# it has bows
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# it has bows
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# does not have bows
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# it has bows
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# it has bows
